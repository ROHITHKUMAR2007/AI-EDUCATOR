# %%
#ROHITH KUMAR S
a = 10
b = 5

print("Before swapping:")
print("a =", a)
print("b =", b)

temp = a
a = b
b = temp

print("\nAfter swapping:")
print("a =", a)
print("b =", b)
# Out:
# Before swapping:
# a = 10
# b = 5
#
# After swapping:
# a = 5
# b = 10
