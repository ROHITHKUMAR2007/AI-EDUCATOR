# %%
#ROHITH KUMAR S
#Part 1: Sorting a unique list
numbers = [14, 7, 22, 3, 18, 10]
num = len(numbers)
print("Original list:", numbers)
for i in range(num):
    for j in range(0, num - i - 1):
        if numbers[j] < numbers[j + 1]:
            numbers[j], numbers[j + 1] = numbers[j + 1], numbers[j]    
    print(f"After pass {i+1}:", numbers)
print("Final sorted list (Descending):", numbers)
# Out:
# Original list: [14, 7, 22, 3, 18, 10]
# After pass 1: [14, 22, 7, 18, 10, 3]
# After pass 2: [22, 14, 18, 10, 7, 3]
# After pass 3: [22, 18, 14, 10, 7, 3]
# After pass 4: [22, 18, 14, 10, 7, 3]
# After pass 5: [22, 18, 14, 10, 7, 3]
# After pass 6: [22, 18, 14, 10, 7, 3]
# Final sorted list (Descending): [22, 18, 14, 10, 7, 3]

# %%
#SAMARUBAN V
#Part 2: Sorting a list with ties
numbers2 = [5, 2, 7, 3, 2, 8, 5, 1]
num2 = len(numbers2)
print("\nOriginal list:", numbers2)````````````
for i in range(num2):
    for j in range(0, num2 - i - 1):
        if numbers2[j] > numbers2[j + 1]:
            numbers2[j], numbers2[j + 1] = numbers2[j + 1], numbers2[j]
    print(f"After pass {i+1}:", numbers2)
print("Final sorted list (Ascending):", numbers2)
print("\nNote: Bubble sort works correctly even with duplicate values.")
# Out:
# Original list: [5, 2, 7, 3, 2, 8, 5, 1]
# After pass 1: [2, 5, 3, 2, 7, 5, 1, 8]
# After pass 2: [2, 3, 2, 5, 5, 1, 7, 8]
# After pass 3: [2, 2, 3, 5, 1, 5, 7, 8]
# After pass 4: [2, 2, 3, 1, 5, 5, 7, 8]
# After pass 5: [2, 2, 1, 3, 5, 5, 7, 8]
# After pass 6: [2, 1, 2, 3, 5, 5, 7, 8]
# After pass 7: [1, 2, 2, 3, 5, 5, 7, 8]
# After pass 8: [1, 2, 2, 3, 5, 5, 7, 8]
# Final sorted list (Ascending): [1, 2, 2, 3, 5, 5, 7, 8]
#
# Note: Bubble sort works correctly even with duplicate values.
